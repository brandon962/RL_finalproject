# %%
#!/usr/bin/env python
import pygame
from __future__ import print_function
import os
os.environ["CUDA_VISIVBLE_DEVICES"] = '0'
import tensorflow as tf
import cv2
import sys
sys.path.append("game/")
import wrapped_flappy_bird as game
import random
import numpy as np
from collections import deque
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
print('tensorflow version: ',tf.__version__)
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 3037498224429934671
# ]
# tensorflow version:  1.10.0

# %%
import pygame
from __future__ import print_function
import numpy as np
from collections import deque
import cv2

# %%
GAME = 'bird' # the name of the game being played for log files
ACTIONS = 2 # number of valid actions
GAMMA = 0.99 # decay rate of past observations
OBSERVE = 10000. # timesteps to observe before training
EXPLORE = 3000000. # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.5 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 32 # size of minibatch
FRAME_PER_ACTION = 1

# %%
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev = 0.01)
    return tf.Variable(initial)

# %%
def bias_variable(shape):
    initial = tf.constant(0.01, shape = shape)
    return tf.Variable(initial)

# %%
def conv2d(x, W, stride):
    return tf.nn.conv2d(x, W, strides = [1, stride, stride, 1], padding = "SAME")

# %%
def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize = [1, 2, 2, 1], strides = [1, 2, 2, 1], padding = "SAME")

# %%
def createNetwork():
    # network weights
    W_conv1 = weight_variable([8, 8, 4, 32])
    b_conv1 = bias_variable([32])

    W_conv2 = weight_variable([4, 4, 32, 64])
    b_conv2 = bias_variable([64])

    W_conv3 = weight_variable([3, 3, 64, 64])
    b_conv3 = bias_variable([64])

    W_fc1 = weight_variable([1600, 512])
    b_fc1 = bias_variable([512])

    W_fc2 = weight_variable([512, ACTIONS])
    b_fc2 = bias_variable([ACTIONS])

    # input layer
    s = tf.placeholder("float", [None, 80, 80, 4])

    # hidden layers
    h_conv1 = tf.nn.relu(conv2d(s, W_conv1, 4) + b_conv1)
    h_pool1 = max_pool_2x2(h_conv1)

    h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2, 2) + b_conv2)
    #h_pool2 = max_pool_2x2(h_conv2)

    h_conv3 = tf.nn.relu(conv2d(h_conv2, W_conv3, 1) + b_conv3)
    #h_pool3 = max_pool_2x2(h_conv3)

    #h_pool3_flat = tf.reshape(h_pool3, [-1, 256])
    h_conv3_flat = tf.reshape(h_conv3, [-1, 1600])

    h_fc1 = tf.nn.relu(tf.matmul(h_conv3_flat, W_fc1) + b_fc1)

    # readout layer
    readout = tf.matmul(h_fc1, W_fc2) + b_fc2

    return s, readout, h_fc1

# %%
def trainNetwork(s, readout, h_fc1, sess):
    # define the cost function
    a = tf.placeholder("float", [None, ACTIONS])
    y = tf.placeholder("float", [None])
    readout_action = tf.reduce_sum(tf.multiply(readout, a), reduction_indices=1)
    cost = tf.reduce_mean(tf.square(y - readout_action))
    train_step = tf.train.AdamOptimizer(1e-6).minimize(cost)

    # open up a game state to communicate with emulator
    game_state = game.GameState()

    # store the previous observations in replay memory
    D = deque()

    # printing
    a_file = open("logs_" + GAME + "/readout.txt", 'w')
    h_file = open("logs_" + GAME + "/hidden.txt", 'w')

    # get the first state by doing nothing and preprocess the image to 80x80x4
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] = 1
    x_t, r_0, terminal = game_state.frame_step(do_nothing)
    x_t = cv2.cvtColor(cv2.resize(x_t, (80, 80)), cv2.COLOR_BGR2GRAY)
    etr, x_t = cv2.threshold(x_t,1,255,cv2.THRESH_BINARY)
    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2)

    # saving and loading networks
    saver = tf.train.Saver()
    sess.run(tf.initialize_all_variables())
    checkpoint = tf.train.get_checkpoint_state("saved_networks")
    if checkpoint and checkpoint.model_checkpoint_path:
        saver.restore(sess, checkpoint.model_checkpoint_path)
        print("Successfully loaded:", checkpoint.model_checkpoint_path)
    else:
        print("Could not find old network weights")

    # start training
    epsilon = INITIAL_EPSILON
    t = 0 
    
    while "flappy bird" != "angry bird":
        # choose an action epsilon greedily
        readout_t = readout.eval(feed_dict={s : [s_t]})[0]
        a_t = np.zeros([ACTIONS])
        action_index = 0
        if t % FRAME_PER_ACTION == 0:
            if random.random() <= epsilon:
                print("----------Random Action----------")
                
                if random.random() < 0.1 :
                    a_t[1] = 1
                    action_index = 1
                else:
                    a_t[0] = 1
                    action_index = 0
            else:
                action_index = np.argmax(readout_t)
                a_t[action_index] = 1
        else:
            a_t[0] = 1 # do nothing

        # scale down epsilon
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE

        # run the selected action and observe next state and reward
        x_t1_colored, r_t, terminal = game_state.frame_step(a_t)
        x_t1 = cv2.cvtColor(cv2.resize(x_t1_colored, (80, 80)), cv2.COLOR_BGR2GRAY)
        ret, x_t1 = cv2.threshold(x_t1, 1, 255, cv2.THRESH_BINARY)
        x_t1 = np.reshape(x_t1, (80, 80, 1))
        #s_t1 = np.append(x_t1, s_t[:,:,1:], axis = 2)
        s_t1 = np.append(x_t1, s_t[:, :, :3], axis=2)

        # store the transition in D
        D.append((s_t, a_t, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        # only train if done observing
        if t > OBSERVE:
            # sample a minibatch to train on
            minibatch = random.sample(D, BATCH)

            # get the batch variables
            s_j_batch = [d[0] for d in minibatch]
            a_batch = [d[1] for d in minibatch]
            r_batch = [d[2] for d in minibatch]
            s_j1_batch = [d[3] for d in minibatch]

            y_batch = []
            readout_j1_batch = readout.eval(feed_dict = {s : s_j1_batch})
            for i in range(0, len(minibatch)):
                terminal = minibatch[i][4]
                # if terminal, only equals reward
                if terminal:
                    y_batch.append(r_batch[i])
                else:
                    y_batch.append(r_batch[i] + GAMMA * np.max(readout_j1_batch[i]))

            # perform gradient step
            train_step.run(feed_dict = {
                y : y_batch,
                a : a_batch,
                s : s_j_batch}
            )

        # update the old values
        s_t = s_t1
        t += 1

        # save progress every 10000 iterations
        if t % 10000 == 0:
            saver.save(sess, 'saved_networks/' + GAME + '-dqn', global_step = t)

        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state, \
            "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t, \
            "/ Q_MAX %e" % np.max(readout_t))
        # write info to files
        '''
        if t % 10000 <= 100:
            a_file.write(",".join([str(x) for x in readout_t]) + '\n')
            h_file.write(",".join([str(x) for x in h_fc1.eval(feed_dict={s:[s_t]})[0]]) + '\n')
            cv2.imwrite("logs_tetris/frame" + str(t) + ".png", x_t1)
        '''

# %%
def playGame():
    sess = tf.InteractiveSession()
    s, readout, h_fc1 = createNetwork()
    trainNetwork(s, readout, h_fc1, sess)

def main():
    playGame()

if __name__ == "__main__":
    main()
# Out:
# WARNING:tensorflow:From C:\Users\flash\Anaconda3\lib\site-packages\tensorflow\python\util\tf_should_use.py:118: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# INFO:tensorflow:Restoring parameters from saved_networks\bird-dqn-10000
# Successfully loaded: saved_networks\bird-dqn-10000
# TIMESTEP 1 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.215087e+01
# ----------Random Action----------
# TIMESTEP 2 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.204418e+01
# TIMESTEP 3 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.191034e+01
# ----------Random Action----------
# TIMESTEP 4 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.184067e+01
# ----------Random Action----------
# TIMESTEP 5 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.187737e+01
# ----------Random Action----------
# TIMESTEP 6 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.189903e+01
# ----------Random Action----------
# TIMESTEP 7 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.182255e+01
# TIMESTEP 8 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.178914e+01
# TIMESTEP 9 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.177470e+01
# TIMESTEP 10 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.187518e+01
# ----------Random Action----------
# TIMESTEP 11 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.196081e+01
# ----------Random Action----------
# TIMESTEP 12 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.197147e+01
# ----------Random Action----------
# TIMESTEP 13 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.191208e+01
# TIMESTEP 14 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.194843e+01
# ----------Random Action----------
# TIMESTEP 15 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.199105e+01
# TIMESTEP 16 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.198683e+01
# ----------Random Action----------
# TIMESTEP 17 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.209599e+01
# TIMESTEP 18 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.214495e+01
# ----------Random Action----------
# TIMESTEP 19 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.218626e+01
# TIMESTEP 20 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.215025e+01
# TIMESTEP 21 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.215403e+01
# TIMESTEP 22 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.222324e+01
# ----------Random Action----------
# TIMESTEP 23 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.215062e+01
# TIMESTEP 24 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.213421e+01
# ----------Random Action----------
# TIMESTEP 25 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.207083e+01
# TIMESTEP 26 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.215812e+01
# TIMESTEP 27 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.218703e+01
# TIMESTEP 28 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.216649e+01
# ----------Random Action----------
# TIMESTEP 29 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.219906e+01
# ----------Random Action----------
# TIMESTEP 30 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.215354e+01
# TIMESTEP 31 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.219997e+01
# ----------Random Action----------
# TIMESTEP 32 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.216736e+01
# ----------Random Action----------
# TIMESTEP 33 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.229816e+01
# TIMESTEP 34 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.222822e+01
# TIMESTEP 35 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.214894e+01
# ----------Random Action----------
# TIMESTEP 36 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.056735e+01
# ----------Random Action----------
# TIMESTEP 37 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 3.424580e+00
# ----------Random Action----------
# TIMESTEP 38 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 4.947577e+00
# TIMESTEP 39 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX -1.451202e+00
# ----------Random Action----------
# TIMESTEP 40 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 6.682944e+00
# ----------Random Action----------
# TIMESTEP 41 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.078907e+01
# ----------Random Action----------
# TIMESTEP 42 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.116280e+01
# TIMESTEP 43 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.246091e+01
# ----------Random Action----------
# TIMESTEP 44 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.252620e+01
# TIMESTEP 45 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.255199e+01
# ----------Random Action----------
# TIMESTEP 46 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.272790e+01
# ----------Random Action----------
# TIMESTEP 47 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.279757e+01
# ----------Random Action----------
# TIMESTEP 48 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.270934e+01
# ----------Random Action----------
# TIMESTEP 49 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.261948e+01
# TIMESTEP 50 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.261658e+01
# TIMESTEP 51 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.254680e+01
# ----------Random Action----------
# TIMESTEP 52 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.255917e+01
# TIMESTEP 53 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 9.137754e+00
# TIMESTEP 54 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD -1 / Q_MAX -9.266765e-01
# ----------Random Action----------
# TIMESTEP 55 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.187792e+01
# ----------Random Action----------
# TIMESTEP 56 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.177983e+01
# TIMESTEP 57 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.174289e+01
# TIMESTEP 58 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.189765e+01
# TIMESTEP 59 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.187205e+01
# ----------Random Action----------
# TIMESTEP 60 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.185127e+01
# TIMESTEP 61 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.184904e+01
# ----------Random Action----------
# TIMESTEP 62 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.192021e+01
# TIMESTEP 63 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.191990e+01
# TIMESTEP 64 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.190763e+01
# TIMESTEP 65 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.187559e+01
# ----------Random Action----------
# TIMESTEP 66 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.192461e+01
# TIMESTEP 67 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.194311e+01
# ----------Random Action----------
# TIMESTEP 68 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193839e+01
# TIMESTEP 69 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.195853e+01
# ----------Random Action----------
# TIMESTEP 70 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.192974e+01
# ----------Random Action----------
# TIMESTEP 71 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.196560e+01
# TIMESTEP 72 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.199478e+01
# TIMESTEP 73 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.207048e+01
# TIMESTEP 74 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.207667e+01
# ----------Random Action----------
# TIMESTEP 75 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.212469e+01
# TIMESTEP 76 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.209520e+01
# ----------Random Action----------
# TIMESTEP 77 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.209480e+01
# TIMESTEP 78 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.202558e+01
# ----------Random Action----------
# TIMESTEP 79 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.211653e+01
# ----------Random Action----------
# TIMESTEP 80 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.207721e+01
# ----------Random Action----------
# TIMESTEP 81 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.224220e+01
# ----------Random Action----------
# TIMESTEP 82 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.229432e+01
# TIMESTEP 83 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.222490e+01
# TIMESTEP 84 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.227765e+01
# ----------Random Action----------
# TIMESTEP 85 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.232348e+01
# ----------Random Action----------
# TIMESTEP 86 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.236263e+01
# ----------Random Action----------
# TIMESTEP 87 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.225242e+01
# TIMESTEP 88 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.225109e+01
# TIMESTEP 89 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.220360e+01
# ----------Random Action----------
# TIMESTEP 90 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.221702e+01
# TIMESTEP 91 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.226899e+01
# ----------Random Action----------
# TIMESTEP 92 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.229257e+01
# ----------Random Action----------
# TIMESTEP 93 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.234730e+01
# ----------Random Action----------
# TIMESTEP 94 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.237432e+01
# ----------Random Action----------
# TIMESTEP 95 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.233491e+01
# TIMESTEP 96 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.234208e+01
# ----------Random Action----------
# TIMESTEP 97 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.240803e+01
# TIMESTEP 98 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 7.192270e+00
# TIMESTEP 99 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 3.723733e+00
# ----------Random Action----------
# TIMESTEP 100 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 2.258132e+00
# ----------Random Action----------
# TIMESTEP 101 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX -7.638313e-01
# TIMESTEP 102 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 2.422007e+00
# ----------Random Action----------
# TIMESTEP 103 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 2.683544e+00
# ----------Random Action----------
# TIMESTEP 104 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD -1 / Q_MAX 2.522865e+00
# TIMESTEP 105 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.177773e+01
# TIMESTEP 106 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.192343e+01
# ----------Random Action----------
# TIMESTEP 107 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.189275e+01
# ----------Random Action----------
# TIMESTEP 108 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.197436e+01
# TIMESTEP 109 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.184634e+01
# ----------Random Action----------
# TIMESTEP 110 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.184272e+01
# ----------Random Action----------
# TIMESTEP 111 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.187158e+01
# ----------Random Action----------
# TIMESTEP 112 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.184820e+01
# TIMESTEP 113 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.183881e+01
# ----------Random Action----------
# TIMESTEP 114 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.189417e+01
# ----------Random Action----------
# TIMESTEP 115 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.195944e+01
# TIMESTEP 116 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.195505e+01
# ----------Random Action----------
# TIMESTEP 117 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.195324e+01
# ----------Random Action----------
# TIMESTEP 118 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193615e+01
# TIMESTEP 119 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.202518e+01
# TIMESTEP 120 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.202246e+01
# ----------Random Action----------
# TIMESTEP 121 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.198365e+01
# ----------Random Action----------
# TIMESTEP 122 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.204616e+01
# TIMESTEP 123 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.209393e+01
# TIMESTEP 124 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.212210e+01
# ----------Random Action----------
# TIMESTEP 125 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.216802e+01
# ----------Random Action----------
# TIMESTEP 126 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.216181e+01
# TIMESTEP 127 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.217159e+01
# ----------Random Action----------
# TIMESTEP 128 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.205509e+01
# ----------Random Action----------
# TIMESTEP 129 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.214786e+01
# TIMESTEP 130 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.212630e+01
# ----------Random Action----------
# TIMESTEP 131 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.222307e+01
# ----------Random Action----------
# TIMESTEP 132 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.228875e+01
# TIMESTEP 133 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.218813e+01
# ----------Random Action----------
# TIMESTEP 134 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.223614e+01
# TIMESTEP 135 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.219715e+01
# ----------Random Action----------
# TIMESTEP 136 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.218929e+01
# ----------Random Action----------
# TIMESTEP 137 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.211630e+01
# ----------Random Action----------
# TIMESTEP 138 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.207671e+01
# ----------Random Action----------
# TIMESTEP 139 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.138623e+01
# ----------Random Action----------
# TIMESTEP 140 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.030692e+01
# TIMESTEP 141 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 5.334681e+00
# TIMESTEP 142 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 4.200897e+00
# ----------Random Action----------
# TIMESTEP 143 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 7.050392e+00
# TIMESTEP 144 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 9.323753e+00
# TIMESTEP 145 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 6.493504e+00
# ----------Random Action----------
# TIMESTEP 146 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.078609e+01
# ----------Random Action----------
# TIMESTEP 147 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.239445e+01
# ----------Random Action----------
# TIMESTEP 148 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.176568e+01
# TIMESTEP 149 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.165854e+01
# ----------Random Action----------
# TIMESTEP 150 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.013227e+01
# TIMESTEP 151 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.143730e+01
# ----------Random Action----------
# TIMESTEP 152 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.251294e+01
# ----------Random Action----------
# TIMESTEP 153 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX -1.962045e+00
# ----------Random Action----------
# TIMESTEP 154 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD -1 / Q_MAX 2.048400e-01
# ----------Random Action----------
# TIMESTEP 155 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.185945e+01
# TIMESTEP 156 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193577e+01
# TIMESTEP 157 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.188512e+01
# ----------Random Action----------
# TIMESTEP 158 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.190212e+01
# TIMESTEP 159 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.186436e+01
# TIMESTEP 160 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.189099e+01
# TIMESTEP 161 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.189276e+01
# ----------Random Action----------
# TIMESTEP 162 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.191957e+01
# ----------Random Action----------
# TIMESTEP 163 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.192028e+01
# TIMESTEP 164 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.197691e+01
# TIMESTEP 165 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.195647e+01
# TIMESTEP 166 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.196325e+01
# TIMESTEP 167 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.195385e+01
# ----------Random Action----------
# TIMESTEP 168 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.192622e+01
# TIMESTEP 169 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.201404e+01
# TIMESTEP 170 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.206570e+01
# TIMESTEP 171 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.208862e+01
# ----------Random Action----------
# TIMESTEP 172 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.218377e+01
# TIMESTEP 173 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.217811e+01
# TIMESTEP 174 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.221166e+01
# ----------Random Action----------
# TIMESTEP 175 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.216936e+01
# ----------Random Action----------
# TIMESTEP 176 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.217021e+01
# TIMESTEP 177 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.218463e+01
# ----------Random Action----------
# TIMESTEP 178 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.216909e+01
# TIMESTEP 179 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.219295e+01
# ----------Random Action----------
# TIMESTEP 180 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.217474e+01
# ----------Random Action----------
# TIMESTEP 181 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.224770e+01
# TIMESTEP 182 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.224160e+01
# TIMESTEP 183 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.219824e+01
# TIMESTEP 184 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.227771e+01
# ----------Random Action----------
# TIMESTEP 185 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.221176e+01
# ----------Random Action----------
# TIMESTEP 186 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.220555e+01
# TIMESTEP 187 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.218755e+01
# TIMESTEP 188 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.217126e+01
# TIMESTEP 189 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.196582e+01
# TIMESTEP 190 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.188408e+01
# ----------Random Action----------
# TIMESTEP 191 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.156590e+01
# TIMESTEP 192 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 4.925596e+00
# TIMESTEP 193 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 8.719270e+00
# TIMESTEP 194 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.167609e+01
# TIMESTEP 195 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.227380e+01
# ----------Random Action----------
# TIMESTEP 196 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.230196e+01
# ----------Random Action----------
# TIMESTEP 197 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.237964e+01
# TIMESTEP 198 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.248478e+01
# TIMESTEP 199 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.248905e+01
# ----------Random Action----------
# TIMESTEP 200 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.272586e+01
# ----------Random Action----------
# TIMESTEP 201 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.274117e+01
# ----------Random Action----------
# TIMESTEP 202 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.268538e+01
# TIMESTEP 203 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX -4.749274e+00
# ----------Random Action----------
# TIMESTEP 204 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD -1 / Q_MAX -2.211080e+00
# TIMESTEP 205 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.177384e+01
# TIMESTEP 206 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.190554e+01
# TIMESTEP 207 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.187252e+01
# TIMESTEP 208 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.189176e+01
# TIMESTEP 209 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.191138e+01
# TIMESTEP 210 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193474e+01
# TIMESTEP 211 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.192233e+01
# ----------Random Action----------
# TIMESTEP 212 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.194586e+01
# ----------Random Action----------
# TIMESTEP 213 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.194906e+01
# TIMESTEP 214 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.191853e+01
# TIMESTEP 215 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.188544e+01
# TIMESTEP 216 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193445e+01
# ----------Random Action----------
# TIMESTEP 217 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193549e+01
# TIMESTEP 218 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.197216e+01
# TIMESTEP 219 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.199664e+01
# TIMESTEP 220 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.207618e+01
# ----------Random Action----------
# TIMESTEP 221 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.208462e+01
# ----------Random Action----------
# TIMESTEP 222 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.219987e+01
# TIMESTEP 223 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.219603e+01
# ----------Random Action----------
# TIMESTEP 224 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.224378e+01
# TIMESTEP 225 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.226342e+01
# TIMESTEP 226 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.218424e+01
# ----------Random Action----------
# TIMESTEP 227 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.218075e+01
# ----------Random Action----------
# TIMESTEP 228 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.209542e+01
# ----------Random Action----------
# TIMESTEP 229 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.217302e+01
# ----------Random Action----------
# TIMESTEP 230 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.218699e+01
# TIMESTEP 231 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.224377e+01
# ----------Random Action----------
# TIMESTEP 232 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.218511e+01
# ----------Random Action----------
# TIMESTEP 233 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.218906e+01
# TIMESTEP 234 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.223256e+01
# TIMESTEP 235 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.217074e+01
# TIMESTEP 236 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.225922e+01
# ----------Random Action----------
# TIMESTEP 237 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.226137e+01
# ----------Random Action----------
# TIMESTEP 238 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.232224e+01
# TIMESTEP 239 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.227696e+01
# ----------Random Action----------
# TIMESTEP 240 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.226310e+01
# TIMESTEP 241 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.237757e+01
# ----------Random Action----------
# TIMESTEP 242 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.231382e+01
# TIMESTEP 243 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.238040e+01
# ----------Random Action----------
# TIMESTEP 244 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.237913e+01
# TIMESTEP 245 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.223048e+01
# ----------Random Action----------
# TIMESTEP 246 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.222825e+01
# ----------Random Action----------
# TIMESTEP 247 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.234337e+01
# ----------Random Action----------
# TIMESTEP 248 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.235933e+01
# TIMESTEP 249 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.229477e+01
# ----------Random Action----------
# TIMESTEP 250 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.248460e+01
# ----------Random Action----------
# TIMESTEP 251 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.252183e+01
# TIMESTEP 252 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.248959e+01
# TIMESTEP 253 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.245360e+01
# ----------Random Action----------
# TIMESTEP 254 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.247969e+01
# TIMESTEP 255 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.246552e+01
# TIMESTEP 256 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.249481e+01
# TIMESTEP 257 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.245972e+01
# TIMESTEP 258 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.253890e+01
# ----------Random Action----------
# TIMESTEP 259 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.260618e+01
# ----------Random Action----------
# TIMESTEP 260 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.263904e+01
# TIMESTEP 261 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.265183e+01
# ----------Random Action----------
# TIMESTEP 262 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.271067e+01
# ----------Random Action----------
# TIMESTEP 263 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.280429e+01
# TIMESTEP 264 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.274280e+01
# TIMESTEP 265 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 1 / Q_MAX 1.290659e+01
# ----------Random Action----------
# TIMESTEP 266 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.206913e+01
# TIMESTEP 267 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.187245e+01
# TIMESTEP 268 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.202015e+01
# TIMESTEP 269 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.205896e+01
# TIMESTEP 270 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.211067e+01
# TIMESTEP 271 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.215680e+01
# TIMESTEP 272 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.220671e+01
# TIMESTEP 273 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.217492e+01
# ----------Random Action----------
# TIMESTEP 274 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.226017e+01
# ----------Random Action----------
# TIMESTEP 275 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.229195e+01
# ----------Random Action----------
# TIMESTEP 276 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.236760e+01
# ----------Random Action----------
# TIMESTEP 277 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.243888e+01
# ----------Random Action----------
# TIMESTEP 278 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.243291e+01
# TIMESTEP 279 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.240474e+01
# ----------Random Action----------
# TIMESTEP 280 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.237058e+01
# ----------Random Action----------
# TIMESTEP 281 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.234864e+01
# ----------Random Action----------
# TIMESTEP 282 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.242028e+01
# TIMESTEP 283 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.242071e+01
# ----------Random Action----------
# TIMESTEP 284 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.243888e+01
# TIMESTEP 285 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.244404e+01
# TIMESTEP 286 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.259493e+01
# ----------Random Action----------
# TIMESTEP 287 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.264469e+01
# TIMESTEP 288 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.266138e+01
# TIMESTEP 289 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.234856e+01
# ----------Random Action----------
# TIMESTEP 290 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.228273e+01
# TIMESTEP 291 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD -1 / Q_MAX 1.257998e+01
# TIMESTEP 292 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.187461e+01
# TIMESTEP 293 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.186910e+01
# TIMESTEP 294 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.182318e+01
# TIMESTEP 295 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.190308e+01
# TIMESTEP 296 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.184072e+01
# ----------Random Action----------
# TIMESTEP 297 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.185866e+01
# ----------Random Action----------
# TIMESTEP 298 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.189410e+01
# ----------Random Action----------
# TIMESTEP 299 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.192084e+01
# TIMESTEP 300 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.194993e+01
# ----------Random Action----------
# TIMESTEP 301 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.199743e+01
# ----------Random Action----------
# TIMESTEP 302 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.196527e+01
# ----------Random Action----------
# TIMESTEP 303 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.190407e+01
# ----------Random Action----------
# TIMESTEP 304 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.191574e+01
# TIMESTEP 305 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.184673e+01
# TIMESTEP 306 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.184960e+01
# TIMESTEP 307 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.201772e+01
# TIMESTEP 308 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.209485e+01
# ----------Random Action----------
# TIMESTEP 309 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.219413e+01
# TIMESTEP 310 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.219096e+01
# TIMESTEP 311 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.215153e+01
# ----------Random Action----------
# TIMESTEP 312 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.224605e+01
# TIMESTEP 313 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.214308e+01
# ----------Random Action----------
# TIMESTEP 314 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.221845e+01
# TIMESTEP 315 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.211274e+01
# TIMESTEP 316 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.211396e+01
# TIMESTEP 317 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.209743e+01
# TIMESTEP 318 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.217189e+01
# ----------Random Action----------
# TIMESTEP 319 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.218320e+01
# ----------Random Action----------
# TIMESTEP 320 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.217924e+01
# TIMESTEP 321 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.222004e+01
# TIMESTEP 322 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.216179e+01
# ----------Random Action----------
# TIMESTEP 323 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.218367e+01
# TIMESTEP 324 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.228464e+01
# ----------Random Action----------
# TIMESTEP 325 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.236585e+01
# TIMESTEP 326 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.229594e+01
# ----------Random Action----------
# TIMESTEP 327 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.226132e+01
# ----------Random Action----------
# TIMESTEP 328 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.225210e+01
# TIMESTEP 329 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.227143e+01
# ----------Random Action----------
# TIMESTEP 330 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.225937e+01
# TIMESTEP 331 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.219966e+01
# ----------Random Action----------
# TIMESTEP 332 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.220248e+01
# TIMESTEP 333 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.220901e+01
# ----------Random Action----------
# TIMESTEP 334 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.233894e+01
# ----------Random Action----------
# TIMESTEP 335 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 7.132766e+00
# ----------Random Action----------
# TIMESTEP 336 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX -8.273821e+00
# ----------Random Action----------
# TIMESTEP 337 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX -8.499545e+00
# ----------Random Action----------
# TIMESTEP 338 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX -8.452577e+00
# ----------Random Action----------
# TIMESTEP 339 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX -6.088442e+00
# ----------Random Action----------
# TIMESTEP 340 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX -3.936136e+00
# ----------Random Action----------
# TIMESTEP 341 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD -1 / Q_MAX 1.907879e+00
# ----------Random Action----------
# TIMESTEP 342 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.189045e+01
# ----------Random Action----------
# TIMESTEP 343 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.190757e+01
# ----------Random Action----------
# TIMESTEP 344 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.177877e+01
# TIMESTEP 345 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.187564e+01
# ----------Random Action----------
# TIMESTEP 346 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.170572e+01
# ----------Random Action----------
# TIMESTEP 347 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.168072e+01
# TIMESTEP 348 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.176266e+01
# ----------Random Action----------
# TIMESTEP 349 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.172526e+01
# TIMESTEP 350 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.173973e+01
# ----------Random Action----------
# TIMESTEP 351 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.173634e+01
# TIMESTEP 352 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.172041e+01
# ----------Random Action----------
# TIMESTEP 353 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.177524e+01
# ----------Random Action----------
# TIMESTEP 354 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.177054e+01
# ----------Random Action----------
# TIMESTEP 355 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.184893e+01
# TIMESTEP 356 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.186102e+01
# ----------Random Action----------
# TIMESTEP 357 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193339e+01
# TIMESTEP 358 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.191819e+01
# TIMESTEP 359 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.203232e+01
# ----------Random Action----------
# TIMESTEP 360 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.207497e+01
# TIMESTEP 361 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.202038e+01
# ----------Random Action----------
# TIMESTEP 362 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.199617e+01
# TIMESTEP 363 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.191015e+01
# TIMESTEP 364 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.205207e+01
# TIMESTEP 365 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.201808e+01
# ----------Random Action----------
# TIMESTEP 366 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.201105e+01
# TIMESTEP 367 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.196872e+01
# TIMESTEP 368 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.207030e+01
# ----------Random Action----------
# TIMESTEP 369 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.209403e+01
# ----------Random Action----------
# TIMESTEP 370 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.213630e+01
# ----------Random Action----------
# TIMESTEP 371 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.218581e+01
# ----------Random Action----------
# TIMESTEP 372 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.214826e+01
# TIMESTEP 373 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.219366e+01
# TIMESTEP 374 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.217185e+01
# ----------Random Action----------
# TIMESTEP 375 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.213767e+01
# ----------Random Action----------
# TIMESTEP 376 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 6.997727e+00
# TIMESTEP 377 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 6.644550e+00
# ----------Random Action----------
# TIMESTEP 378 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX -2.961388e+00
# ----------Random Action----------
# TIMESTEP 379 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX -3.642035e+00
# TIMESTEP 380 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX -2.252532e+00
# ----------Random Action----------
# TIMESTEP 381 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX -4.266231e+00
# TIMESTEP 382 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX -2.230852e+00
# TIMESTEP 383 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX -2.643345e-01
# TIMESTEP 384 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.516459e+00
# TIMESTEP 385 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 9.831539e-01
# ----------Random Action----------
# TIMESTEP 386 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX -1.728372e+00
# ----------Random Action----------
# TIMESTEP 387 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX -2.041767e+00
# TIMESTEP 388 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX -1.996761e+00
# ----------Random Action----------
# TIMESTEP 389 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX -1.610633e+00
# TIMESTEP 390 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX -1.879992e+00
# TIMESTEP 391 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD -1 / Q_MAX 9.262493e-01
# TIMESTEP 392 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.192679e+01
# TIMESTEP 393 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.191710e+01
# ----------Random Action----------
# TIMESTEP 394 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.190211e+01
# TIMESTEP 395 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.187971e+01
# TIMESTEP 396 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.191223e+01
# TIMESTEP 397 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.191299e+01
# ----------Random Action----------
# TIMESTEP 398 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.194502e+01
# ----------Random Action----------
# TIMESTEP 399 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193953e+01
# ----------Random Action----------
# TIMESTEP 400 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193101e+01
# TIMESTEP 401 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.195519e+01
# ----------Random Action----------
# TIMESTEP 402 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.195347e+01
# TIMESTEP 403 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.192902e+01
# TIMESTEP 404 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.189799e+01
# TIMESTEP 405 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.197833e+01
# ----------Random Action----------
# TIMESTEP 406 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.205538e+01
# TIMESTEP 407 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.209303e+01
# TIMESTEP 408 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.205595e+01
# ----------Random Action----------
# TIMESTEP 409 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.208781e+01
# TIMESTEP 410 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.211572e+01
# ----------Random Action----------
# TIMESTEP 411 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.222150e+01
# ----------Random Action----------
# TIMESTEP 412 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.219582e+01
# TIMESTEP 413 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.214821e+01
# ----------Random Action----------
# TIMESTEP 414 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.213554e+01
# TIMESTEP 415 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.206084e+01
# TIMESTEP 416 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.209752e+01
# ----------Random Action----------
# TIMESTEP 417 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.210703e+01
# TIMESTEP 418 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.220894e+01
# TIMESTEP 419 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.227139e+01
# TIMESTEP 420 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.223861e+01
# TIMESTEP 421 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.232667e+01
# ----------Random Action----------
# TIMESTEP 422 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.228326e+01
# TIMESTEP 423 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.233233e+01
# TIMESTEP 424 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.230693e+01
# TIMESTEP 425 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.233907e+01
# ----------Random Action----------
# TIMESTEP 426 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.236111e+01
# ----------Random Action----------
# TIMESTEP 427 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.233189e+01
# TIMESTEP 428 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.238106e+01
# ----------Random Action----------
# TIMESTEP 429 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.237882e+01
# ----------Random Action----------
# TIMESTEP 430 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.241592e+01
# TIMESTEP 431 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.243350e+01
# ----------Random Action----------
# TIMESTEP 432 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.241316e+01
# ----------Random Action----------
# TIMESTEP 433 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.241576e+01
# TIMESTEP 434 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.248043e+01
# ----------Random Action----------
# TIMESTEP 435 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.255354e+01
# ----------Random Action----------
# TIMESTEP 436 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.253846e+01
# ----------Random Action----------
# TIMESTEP 437 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.264706e+01
# TIMESTEP 438 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.265333e+01
# TIMESTEP 439 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.265293e+01
# ----------Random Action----------
# TIMESTEP 440 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.257185e+01
# TIMESTEP 441 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.256909e+01
# ----------Random Action----------
# TIMESTEP 442 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.263238e+01
# TIMESTEP 443 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.269612e+01
# ----------Random Action----------
# TIMESTEP 444 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.270167e+01
# TIMESTEP 445 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.280410e+01
# TIMESTEP 446 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.272087e+01
# TIMESTEP 447 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.280162e+01
# TIMESTEP 448 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.278224e+01
# TIMESTEP 449 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.283837e+01
# TIMESTEP 450 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.299872e+01
# ----------Random Action----------
# TIMESTEP 451 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.297643e+01
# ----------Random Action----------
# TIMESTEP 452 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 1 / Q_MAX 1.307121e+01
# TIMESTEP 453 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.223561e+01
# TIMESTEP 454 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.201639e+01
# TIMESTEP 455 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.207904e+01
# ...
# ----------Random Action----------
# TIMESTEP 9862 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.139260e+01
# ----------Random Action----------
# TIMESTEP 9863 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.164863e+01
# TIMESTEP 9864 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.120220e+01
# TIMESTEP 9865 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.057131e+01
# TIMESTEP 9866 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.165915e+01
# TIMESTEP 9867 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.200709e+01
# TIMESTEP 9868 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.216367e+01
# ----------Random Action----------
# TIMESTEP 9869 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.214191e+01
# TIMESTEP 9870 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.214847e+01
# ----------Random Action----------
# TIMESTEP 9871 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.224898e+01
# TIMESTEP 9872 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.234787e+01
# TIMESTEP 9873 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.238172e+01
# TIMESTEP 9874 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.239851e+01
# TIMESTEP 9875 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.248777e+01
# TIMESTEP 9876 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.251481e+01
# TIMESTEP 9877 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.250223e+01
# ----------Random Action----------
# TIMESTEP 9878 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.254280e+01
# TIMESTEP 9879 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.248746e+01
# TIMESTEP 9880 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.249327e+01
# ----------Random Action----------
# TIMESTEP 9881 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.250649e+01
# ----------Random Action----------
# TIMESTEP 9882 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.256410e+01
# TIMESTEP 9883 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.251958e+01
# ----------Random Action----------
# TIMESTEP 9884 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 8.849740e+00
# TIMESTEP 9885 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 6.149516e+00
# ----------Random Action----------
# TIMESTEP 9886 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 8.387696e+00
# TIMESTEP 9887 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 9.643189e+00
# ----------Random Action----------
# TIMESTEP 9888 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD -1 / Q_MAX 7.424941e+00
# ----------Random Action----------
# TIMESTEP 9889 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.181345e+01
# ----------Random Action----------
# TIMESTEP 9890 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.191687e+01
# TIMESTEP 9891 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.187936e+01
# ----------Random Action----------
# TIMESTEP 9892 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.184603e+01
# TIMESTEP 9893 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.171640e+01
# ----------Random Action----------
# TIMESTEP 9894 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.163218e+01
# ----------Random Action----------
# TIMESTEP 9895 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.166446e+01
# ----------Random Action----------
# TIMESTEP 9896 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.171512e+01
# TIMESTEP 9897 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.175978e+01
# ----------Random Action----------
# TIMESTEP 9898 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.176076e+01
# TIMESTEP 9899 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.184930e+01
# TIMESTEP 9900 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.187574e+01
# TIMESTEP 9901 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.187182e+01
# ----------Random Action----------
# TIMESTEP 9902 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.181708e+01
# TIMESTEP 9903 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.190310e+01
# TIMESTEP 9904 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193877e+01
# ----------Random Action----------
# TIMESTEP 9905 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.197316e+01
# ----------Random Action----------
# TIMESTEP 9906 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.197039e+01
# TIMESTEP 9907 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.206705e+01
# TIMESTEP 9908 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.215373e+01
# ----------Random Action----------
# TIMESTEP 9909 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.216356e+01
# TIMESTEP 9910 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.219447e+01
# ----------Random Action----------
# TIMESTEP 9911 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.225676e+01
# ----------Random Action----------
# TIMESTEP 9912 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.215260e+01
# TIMESTEP 9913 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.221679e+01
# ----------Random Action----------
# TIMESTEP 9914 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.224310e+01
# TIMESTEP 9915 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.236504e+01
# TIMESTEP 9916 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.240231e+01
# TIMESTEP 9917 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.236450e+01
# TIMESTEP 9918 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.243149e+01
# ----------Random Action----------
# TIMESTEP 9919 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.235343e+01
# TIMESTEP 9920 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.229950e+01
# ----------Random Action----------
# TIMESTEP 9921 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.216940e+01
# ----------Random Action----------
# TIMESTEP 9922 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.203783e+01
# ----------Random Action----------
# TIMESTEP 9923 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.149017e+01
# ----------Random Action----------
# TIMESTEP 9924 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.147596e+01
# TIMESTEP 9925 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.156104e+01
# ----------Random Action----------
# TIMESTEP 9926 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 9.275002e+00
# TIMESTEP 9927 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.136598e+01
# TIMESTEP 9928 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.254210e+01
# ----------Random Action----------
# TIMESTEP 9929 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.259052e+01
# ----------Random Action----------
# TIMESTEP 9930 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.262229e+01
# ----------Random Action----------
# TIMESTEP 9931 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.274730e+01
# ----------Random Action----------
# TIMESTEP 9932 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.269903e+01
# TIMESTEP 9933 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.262952e+01
# TIMESTEP 9934 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.265536e+01
# ----------Random Action----------
# TIMESTEP 9935 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.268340e+01
# TIMESTEP 9936 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.268543e+01
# ----------Random Action----------
# TIMESTEP 9937 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.264328e+01
# ----------Random Action----------
# TIMESTEP 9938 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.268732e+01
# ----------Random Action----------
# TIMESTEP 9939 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.267073e+01
# TIMESTEP 9940 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.270003e+01
# ----------Random Action----------
# TIMESTEP 9941 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.263290e+01
# TIMESTEP 9942 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.278255e+01
# TIMESTEP 9943 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.278938e+01
# ----------Random Action----------
# TIMESTEP 9944 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.282096e+01
# TIMESTEP 9945 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.285497e+01
# ----------Random Action----------
# TIMESTEP 9946 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.289781e+01
# TIMESTEP 9947 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.302722e+01
# TIMESTEP 9948 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.303073e+01
# TIMESTEP 9949 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 1 / Q_MAX 1.304240e+01
# ----------Random Action----------
# TIMESTEP 9950 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.224776e+01
# TIMESTEP 9951 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.205348e+01
# ----------Random Action----------
# TIMESTEP 9952 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.213944e+01
# ----------Random Action----------
# TIMESTEP 9953 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.213120e+01
# TIMESTEP 9954 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.221229e+01
# TIMESTEP 9955 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.223934e+01
# ----------Random Action----------
# TIMESTEP 9956 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.229586e+01
# TIMESTEP 9957 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.222034e+01
# TIMESTEP 9958 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.231254e+01
# ----------Random Action----------
# TIMESTEP 9959 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.237510e+01
# TIMESTEP 9960 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.238069e+01
# ----------Random Action----------
# TIMESTEP 9961 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.234029e+01
# TIMESTEP 9962 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.235024e+01
# ----------Random Action----------
# TIMESTEP 9963 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.246575e+01
# TIMESTEP 9964 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.246300e+01
# TIMESTEP 9965 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.247287e+01
# ----------Random Action----------
# TIMESTEP 9966 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.249338e+01
# ----------Random Action----------
# TIMESTEP 9967 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.250549e+01
# TIMESTEP 9968 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.253387e+01
# ----------Random Action----------
# TIMESTEP 9969 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.254632e+01
# TIMESTEP 9970 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.268039e+01
# TIMESTEP 9971 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.267643e+01
# ----------Random Action----------
# TIMESTEP 9972 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.264242e+01
# TIMESTEP 9973 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.259492e+01
# TIMESTEP 9974 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.262352e+01
# TIMESTEP 9975 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.261378e+01
# TIMESTEP 9976 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.265311e+01
# ----------Random Action----------
# TIMESTEP 9977 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD -1 / Q_MAX 1.270984e+01
# TIMESTEP 9978 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.182596e+01
# ----------Random Action----------
# TIMESTEP 9979 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.191446e+01
# ----------Random Action----------
# TIMESTEP 9980 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.188736e+01
# ----------Random Action----------
# TIMESTEP 9981 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.190308e+01
# ----------Random Action----------
# TIMESTEP 9982 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.184072e+01
# ----------Random Action----------
# TIMESTEP 9983 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.185866e+01
# TIMESTEP 9984 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.179096e+01
# ----------Random Action----------
# TIMESTEP 9985 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.179363e+01
# TIMESTEP 9986 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.179915e+01
# TIMESTEP 9987 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193455e+01
# TIMESTEP 9988 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193886e+01
# TIMESTEP 9989 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193112e+01
# ----------Random Action----------
# TIMESTEP 9990 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.195639e+01
# ----------Random Action----------
# TIMESTEP 9991 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.192311e+01
# TIMESTEP 9992 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.198096e+01
# TIMESTEP 9993 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.198358e+01
# TIMESTEP 9994 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.201080e+01
# ----------Random Action----------
# TIMESTEP 9995 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.210038e+01
# ----------Random Action----------
# TIMESTEP 9996 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.212995e+01
# TIMESTEP 9997 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.217878e+01
# TIMESTEP 9998 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.218421e+01
# TIMESTEP 9999 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.220280e+01
# ----------Random Action----------
# TIMESTEP 10000 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.222716e+01
# ----------Random Action----------
# TIMESTEP 10001 / STATE explore / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.216143e+01
# TIMESTEP 10002 / STATE explore / EPSILON 0.49999983336666665 / ACTION 0 / REWARD 0.1 / Q_MAX 1.213372e+01
# ----------Random Action----------
# TIMESTEP 10003 / STATE explore / EPSILON 0.4999996667333333 / ACTION 0 / REWARD 0.1 / Q_MAX 1.212471e+01
# ----------Random Action----------
# TIMESTEP 10004 / STATE explore / EPSILON 0.49999950009999994 / ACTION 1 / REWARD 0.1 / Q_MAX 1.215249e+01
# TIMESTEP 10005 / STATE explore / EPSILON 0.4999993334666666 / ACTION 0 / REWARD 0.1 / Q_MAX 1.216992e+01
# ----------Random Action----------
# TIMESTEP 10006 / STATE explore / EPSILON 0.49999916683333323 / ACTION 0 / REWARD 0.1 / Q_MAX 1.214609e+01
# TIMESTEP 10007 / STATE explore / EPSILON 0.4999990001999999 / ACTION 0 / REWARD 0.1 / Q_MAX 1.222924e+01
# ----------Random Action----------
# TIMESTEP 10008 / STATE explore / EPSILON 0.4999988335666665 / ACTION 0 / REWARD 0.1 / Q_MAX 1.218882e+01
# ----------Random Action----------
# TIMESTEP 10009 / STATE explore / EPSILON 0.49999866693333317 / ACTION 0 / REWARD 0.1 / Q_MAX 1.222443e+01
# ----------Random Action----------
# TIMESTEP 10010 / STATE explore / EPSILON 0.4999985002999998 / ACTION 0 / REWARD 0.1 / Q_MAX 1.222479e+01
# ----------Random Action----------
# TIMESTEP 10011 / STATE explore / EPSILON 0.49999833366666646 / ACTION 0 / REWARD 0.1 / Q_MAX 1.227346e+01
# ----------Random Action----------
